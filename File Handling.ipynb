# %% [markdown]
# ## File Handling in python

# %% [markdown]
# * file operations such as opening a file, reading from it,writing into it, closing it, renaming a file, deleting a file and various file methods.
#
# * To store data temporarily and permanently, we use files.
#
# * A file is the collection of data stored on a disk in one unit identified by
#
# ### Types of File
#
# * Text File: Text file usually we use to store character data.For example,test.txt
# * Binary File: The binary files are used to store binary data such as images,video files,audio files,etc.

# %% [markdown]
# ### File Path
# A file path defines the location of a file or folder in the computer system.
# There are two ways to specify a file path.
#
# * Absolute path:which always begins with the root folder.
# * Relative path: which is relative to the program's current working directory.
#
#
# The absolute path includes the complete directory lis required to locate the file.

# %%
f1=open(r"C:\Users\deepakkumar\OneDrive\Desktop\Demo.txt","r+")

# %%
f1.read()
# Out:
# 'hello good afternoon'

# %%
f1.write("how are you")
# Out:
# 11

# %%
f1.close()

# %%
f1=open(r"C:\Users\deepakkumar\OneDrive\Desktop\Demo.txt","r+")

# %%
f1.read()
# Out:
# 'studentshow are you'

# %%
f1.close()

# %%
f2=open("info.txt","r")

# %%
f2.read()
# Out:
# 'good morning \nhi how are you'

# %%
f2.close()

# %%
f3=open("demo.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 f3=open("demo.txt")
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'demo.txt'

# %%
f4 = open("temp.txt","w")
f4.write("i am a dsa")
f4.close()

# %%
f5 = open("D:\\neat download\\deepak.txt", "w")

# %%
f5.write("hello i am from salem")
# Out:
# 21

# %%
f5.close()

# %%
f6= open("D:\\neat download\\deepak.txt", "a")
f6.write("\n i am studying in besant tech")
f6.close()

# %%
file rename 
copy the file 
adding content to particular position

# %%
import os

# %%
os.remove("D:\\neat download\\deepak.txt")

# %%
f7=open(r"D:\neat download\deepak.txt","w")

# %%
f7.write("python file handling,created for rename the file and and adding text in particular position")
# Out:
# 91

# %%
f7.close()

# %%
f7=open(r"D:\neat download\deepak.txt","r")

# %%
f7.read()
# Out:
# 'python file handling,created for rename the file and and adding text in particular position'

# %%
f7.close()

# %%
import os

old_path= r"D:\neat download\deepak.txt"
new_path= r"D:\neat download\filehandling.txt"

# %%
os.rename(old_path,new_path)

# %%
os.remove(r"D:\neat download\filehandling.txt")

# %%
f7 = open(r"D:\neat download\filehandling.txt","a")
f7.write("python file handling completed")
f7.close()
f7=open(r"D:\neat download\filehandling.txt","r")
f7.read()
# Out:
# '\n python file handling completed\n python file handling completed\n python file handling completedpython file handling completed'

# %%
f1=open(r"C:\Users\deepakkumar\OneDrive\Desktop\Demo.txt","r+")
data=f1.read()

# %%
text="students"
pos=6
f1=open(r"C:\Users\deepakkumar\OneDrive\Desktop\Demo.txt","w")

# %%
new_data=data[:pos]+text+data[pos:]
f1.write(new_data)
# Out:
# 28

# %%
f1=open(r"C:\Users\deepakkumar\OneDrive\Desktop\Demo.txt","r")
f1.read()
# Out:
# 'hello studentsgood afternoon'
